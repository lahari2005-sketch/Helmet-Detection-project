# %% [markdown]
# <a href="https://colab.research.google.com/github/lahari2005-sketch/Helmet-Detection-project/blob/main/Helmet_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17726, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 17726 (delta 50), reused 29 (delta 29), pack-reused 17642 (from 3)
# Receiving objects: 100% (17726/17726), 17.10 MiB | 17.80 MiB/s, done.
# Resolving deltas: 100% (12039/12039), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.1 MB/s eta 0:00:00
# ...

# %%
import torch

# Load pretrained YOLOv5s model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/hub.py:330: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# ...

# %%
from google.colab import files
uploaded = files.upload()

img = list(uploaded.keys())[0]  # get uploaded image filename

# Perform inference
results = model(img)

# Show results
results.show()
# Out:
#      <input type="file" id="files-ae27989d-1f17-48c5-a99c-b8edf9794c48" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae27989d-1f17-48c5-a99c-b8edf9794c48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls /content
# Out:
# drive  sample_data  yolov5

# %%
import zipfile
import os

zip_path = "/C:\Users\Admin\Downloads\helmet-dataset.zip"  # name of uploaded file
extract_path = "/C:\Users\Admin\Downloads\helmet-dataset\helmet-dataset"
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Dataset extracted successfully!")
# !ls /content/helmet-dataset.zip
# Out:
#   File "/tmp/ipython-input-311743520.py", line 4
#     zip_path = "/C:\Users\Admin\Downloads\helmet-dataset.zip"  # name of uploaded file
#                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 3-4: truncated \UXXXXXXXX escape

# %%
# !ls /content/helmet-dataset/runs/train/exp/weights/
# Out:
# ls: cannot access '/content/helmet-dataset/runs/train/exp/weights/': No such file or directory
